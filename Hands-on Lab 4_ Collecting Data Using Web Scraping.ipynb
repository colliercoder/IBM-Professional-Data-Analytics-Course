# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Extract information from a given web site
# *   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(data,"html5lib")

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Salary survey results of programming languages
#   </title>
#   <style>
#    table, th, td {
#   border: 1px solid black;
# }
#   </style>
#  </head>
#  <body>
#   <hr/>
#   <h2>
#    Popular Programming Languages
#   </h2>
#   <hr/>
#   <p>
#    Finding out which is the best language is a tough task. A programming language is created to solve a specific problem. A language which is good for task A may not be able to properly handle task B. Comparing programming language is never easy. What we can do, however, is find which is popular in the industry.
#   </p>
#   <p>
#    There are many ways to find the popularity of a programming languages. Counting the number of google searchs for each language is a simple way to find the popularity. GitHub and StackOverflow also can give some good pointers.
#   </p>
#   <p>
# ...

# %%
table = soup.find('table')
print(table.prettify())
# Out:
# <table>
#  <tbody>
#   <tr>
#    <td>
#     No.
#    </td>
#    <td>
#     Language
#    </td>
#    <td>
#     Created By
#    </td>
#    <td>
#     Average Annual Salary
#    </td>
#    <td>
#     Learning Difficulty
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td>
#     Python
#    </td>
#    <td>
#     Guido van Rossum
#    </td>
#    <td>
#     $114,383
#    </td>
#    <td>
#     Easy
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td>
#     Java
#    </td>
#    <td>
#     James Gosling
#    </td>
#    <td>
#     $101,013
#    </td>
#    <td>
#     Easy
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td>
#     R
#    </td>
#    <td>
#     Robert Gentleman, Ross Ihaka
#    </td>
#    <td>
#     $92,037
#    </td>
#    <td>
#     Hard
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td>
#     Javascript
#    </td>
#    <td>
#     Netscape
#    </td>
#    <td>
#     $110,981
#    </td>
#    <td>
#     Easy
# ...

# %%
for row in table.find_all('tr'):
    cols = row.find_all('td')
    Language = cols[1].string
    AverageAnnualSalary = cols[3].string
    #print("{}--->{}".format(Language,AverageAnnualSalary))
    print(Language,AverageAnnualSalary)
# Out:
# Language Average Annual Salary
# Python $114,383
# Java $101,013
# R $92,037
# Javascript $110,981
# Swift $130,801
# C++ $113,865
# C# $88,726
# PHP $84,727
# SQL $84,793
# Go $94,082

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
# your code goes here
import pandas as pd

# %%
language_data = pd.DataFrame(columns = ['Language','Average Annual Salary'])

for row in table.find_all("tr"):
    cols = row.find_all("td")
    Language = cols[1].text
    AverageAnnualSalary = cols[3].text
    language_data = language_data.append({'Language':Language,'Average Annual Salary':AverageAnnualSalary}, ignore_index =True)

# %%
language_data.head(10)
# Out:
#       Language Average Annual Salary
# 1       Python              $114,383
# 2         Java              $101,013
# 3            R               $92,037
# 4   Javascript              $110,981
# 5        Swift              $130,801
# 6          C++              $113,865
# 7           C#               $88,726
# 8          PHP               $84,727
# 9          SQL               $84,793
# 10          Go               $94,082

# %%
language_data.drop(index=language_data.index[0], 
        axis=0, 
        inplace=True)
language_data.head()
# Out:
#      Language Average Annual Salary
# 1      Python              $114,383
# 2        Java              $101,013
# 3           R               $92,037
# 4  Javascript              $110,981
# 5       Swift              $130,801

# %%
language_data.to_csv(index=False)
# Out:
# 'Language,Average Annual Salary\nPython,"$114,383"\nJava,"$101,013"\nR,"$92,037"\nJavascript,"$110,981"\nSwift,"$130,801"\nC++,"$113,865"\nC#,"$88,726"\nPHP,"$84,727"\nSQL,"$84,793"\nGo,"$94,082"\n'

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01).
